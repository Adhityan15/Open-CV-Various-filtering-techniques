# %%
import cv2
import matplotlib.pyplot as plt

# Load image
img = cv2.imread("input.jpeg", 0)

if img is None:
    print("ERROR: Image not loaded")
    exit()

# Resize for speed
img = cv2.resize(img, (256, 256))

# Apply filters
mean = cv2.blur(img, (3, 3))
gaussian = cv2.GaussianBlur(img, (3, 3), 0)
median = cv2.medianBlur(img, 3)
bilateral = cv2.bilateralFilter(img, 3, 30, 30)
laplacian = cv2.Laplacian(img, cv2.CV_64F)

# Plot results
titles = ["Original", "Mean", "Gaussian", "Median", "Bilateral", "Laplacian"]
images = [img, mean, gaussian, median, bilateral, laplacian]

plt.figure(figsize=(10, 6))
for i in range(6):
    plt.subplot(2, 3, i+1)
    plt.imshow(images[i], cmap="gray")
    plt.title(titles[i])
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("input1.jpg", 0)
img = cv2.resize(img, (256, 256))

mean = cv2.blur(img, (5, 5))


plt.imshow(mean, cmap="gray")
plt.title("Mean (Average) Filtering")
plt.axis("off")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("input2.jpg", 0)
img = cv2.resize(img, (256, 256))

gaussian = cv2.GaussianBlur(img, (5, 5), 0)

plt.imshow(gaussian, cmap="gray")
plt.title("Gaussian Filtering")
plt.axis("off")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("input3.jpg", 0)
img = cv2.resize(img, (256, 256))

median = cv2.medianBlur(img, 5)

plt.imshow(median, cmap="gray")
plt.title("Median Filtering")
plt.axis("off")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("input4.jpg", 0)
img = cv2.resize(img, (256, 256))

bilateral = cv2.bilateralFilter(img, 5, 50, 50)

plt.imshow(bilateral, cmap="gray")
plt.title("Bilateral Filtering")
plt.axis("off")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("input5.jpg", 0)
img = cv2.resize(img, (256, 256))

laplacian = cv2.Laplacian(img, cv2.CV_64F)

plt.imshow(laplacian, cmap="gray")
plt.title("Laplacian Edge Detection")
plt.axis("off")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Read and resize image
img = cv2.imread("input1.jpg", 0)
img = cv2.resize(img, (256, 256))

# Apply Mean (Average) filter
mean = cv2.blur(img, (5, 5))

# Display original and mean-filtered images side by side
plt.figure(figsize=(10,5))

# Original image
plt.subplot(1, 2, 1)
plt.imshow(img, cmap="gray")
plt.title("Original Image")
plt.axis("off")

# Mean filtered image
plt.subplot(1, 2, 2)
plt.imshow(mean, cmap="gray")
plt.title("Mean (Average) Filtering")
plt.axis("off")

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Read and resize image
img = cv2.imread("input2.jpg", 0)
img = cv2.resize(img, (256, 256))

# Apply Gaussian filter
gaussian = cv2.GaussianBlur(img, (5, 5), 0)

# Display original and filtered images side by side
plt.figure(figsize=(10,5))

# Original image
plt.subplot(1, 2, 1)
plt.imshow(img, cmap="gray")
plt.title("Original Image")
plt.axis("off")

# Gaussian filtered image
plt.subplot(1, 2, 2)
plt.imshow(gaussian, cmap="gray")
plt.title("Gaussian Filtering")
plt.axis("off")

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Read and resize image
img = cv2.imread("input3.jpg", 0)
img = cv2.resize(img, (256, 256))

# Apply Median filter
median = cv2.medianBlur(img, 5)

# Display original and median-filtered images side by side
plt.figure(figsize=(10,5))

# Original image
plt.subplot(1, 2, 1)
plt.imshow(img, cmap="gray")
plt.title("Original Image")
plt.axis("off")

# Median filtered image
plt.subplot(1, 2, 2)
plt.imshow(median, cmap="gray")
plt.title("Median Filtering")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(255.5), np.float64(255.5), np.float64(-0.5))

# %%
import cv2
import matplotlib.pyplot as plt

# Read and resize image
img = cv2.imread("input4.jpg", 0)
img = cv2.resize(img, (256, 256))

# Apply Bilateral filter
bilateral = cv2.bilateralFilter(img, 5, 50, 50)

# Display original and bilateral-filtered images side by side
plt.figure(figsize=(10,5))

# Original image
plt.subplot(1, 2, 1)
plt.imshow(img, cmap="gray")
plt.title("Original Image")
plt.axis("off")

# Bilateral filtered image
plt.subplot(1, 2, 2)
plt.imshow(bilateral, cmap="gray")
plt.title("Bilateral Filtering")
plt.axis("off")

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Read and resize image
img = cv2.imread("input5.jpg", 0)
img = cv2.resize(img, (256, 256))

# Apply Laplacian edge detection
laplacian = cv2.Laplacian(img, cv2.CV_64F)

# Display original and Laplacian images side by side
plt.figure(figsize=(10,5))

# Original image
plt.subplot(1, 2, 1)
plt.imshow(img, cmap="gray")
plt.title("Original Image")
plt.axis("off")

# Laplacian edge detection result
plt.subplot(1, 2, 2)
plt.imshow(laplacian, cmap="gray")
plt.title("Laplacian Edge Detection")
plt.axis("off")

plt.show()
